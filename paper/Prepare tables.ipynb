# %%
import pandas as pd

# %%
results = pd.read_csv("/home/b.dolicki/logs/final_table/08082022_test.csv")

# %%
results = results[results["method"].str.contains("linear")][["method", "dataset", "avg_acc", "std_acc"]].round(2)#.pivot(index='method', columns='dataset')

# %%
results
# Out:
#                              method   dataset  avg_acc  std_acc
# 5            linear_bach_no_rot_aug      bach    77.50     0.00
# 6                       linear_bach      bach    77.50     0.00
# 7                    linear_bach_e2      bach    72.50     0.00
# 8                linear_bach_10perc      bach    72.50     0.00
# 9             linear_bach_e2_10perc      bach    70.00     0.00
# 10                linear_bach_1perc      bach    72.50     0.00
# 11             linear_bach_e2_1perc      bach    74.17     1.18
# 17             linear_breakhis_moco  breakhis    93.17     0.21
# 18  linear_breakhis_moco_no_rot_aug  breakhis    92.54     0.00
# 19          linear_breakhis_moco_e2  breakhis    92.92     0.00
# 20           linear_breakhis_10perc  breakhis    90.18     0.16
# 21        linear_breakhis_e2_10perc  breakhis    90.31     0.24
# 22            linear_breakhis_1perc  breakhis    81.25     0.12
# 23    linear_breakhis_moco_e2_1perc  breakhis    83.44     0.00
# ...

# %%
# results["std_acc"] = "$ \pm $ "+results["std_acc"].astype(str)

# %%
results["std_acc"]
# Out:
# 5     0.00
# 6     0.00
# 7     0.00
# 8     0.00
# 9     0.00
# 10    0.00
# 11    1.18
# 14    0.21
# 18    0.21
# 19    0.00
# 20    0.00
# 21    0.16
# 22    0.24
# 23    0.12
# 24    0.00
# 30    0.01
# 31    0.08
# 32    0.01
# 33    0.03
# 34    0.01
# 35    0.03
# 36    0.01
# 37    0.60
# 38    0.37
# 39    0.15
# 40    0.11
# 41    0.50
# 42    0.22
# 43    0.69
# Name: std_acc, dtype: float64

# %%
print(results[results["method"].str.contains("linear")][["method", "avg_acc", "std_acc"]].to_latex(index=False))
# Out:
# \begin{tabular}{lrr}
# \toprule
#                          method &  avg\_acc &  std\_acc \\
# \midrule
#          linear\_bach\_no\_rot\_aug &    77.50 &     0.00 \\
#                     linear\_bach &    77.50 &     0.00 \\
#                  linear\_bach\_e2 &    72.50 &     0.00 \\
#              linear\_bach\_10perc &    72.50 &     0.00 \\
#           linear\_bach\_e2\_10perc &    70.00 &     0.00 \\
#               linear\_bach\_1perc &    72.50 &     0.00 \\
#            linear\_bach\_e2\_1perc &    74.17 &     1.18 \\
#            linear\_breakhis\_moco &    93.17 &     0.21 \\
#            linear\_breakhis\_moco &    93.17 &     0.21 \\
# linear\_breakhis\_moco\_no\_rot\_aug &    92.54 &     0.00 \\
#         linear\_breakhis\_moco\_e2 &    92.92 &     0.00 \\
#          linear\_breakhis\_10perc &    90.18 &     0.16 \\
#       linear\_breakhis\_e2\_10perc &    90.31 &     0.24 \\
#           linear\_breakhis\_1perc &    81.25 &     0.12 \\
# ...
